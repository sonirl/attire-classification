# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
saree_img_link = []
jeans_img_link = []
shorts_img_link = []
shirts_img_link = []

# %%
def product_images(url,product_link):
    
    product = input('Enter the name : ')
    driver = webdriver.Chrome(r'C:/Flip Robo/Image Scraping and Classification Project/data collection/chromedriver.exe')
    driver.maximize_window() #maximizing browser windows
    driver.get(url)
    
    #search tab
    search_bar = driver.find_element_by_id('twotabsearchtextbox')
    search_bar.click()
    search_bar.send_keys(product)
    search_but = driver.find_element_by_id('nav-search-submit-text')
    search_but.click()
    
    for page in range(0,6):
        
        #image element
#         WebDriverWait(driver,2).until(EC.presence_of_all_elements_located((By.CLASS_NAME, 's-image')))
        images = driver.find_elements_by_xpath("//img[@class='s-image']")
        
        for i in images:
            img_link = i.get_attribute('src')
            if img_link is not None:
                if(img_link[0:5]=='https'):
                    product_link.append(img_link)
            
    
        pagination = driver.find_element_by_xpath("//ul[@class='a-pagination']")
        next_page = pagination.find_element_by_xpath(".//li[@class='a-last']")
        next_page.click()
        time.sleep(2)

# %%
product_images('https://www.amazon.in/',saree_img_link)
# Out:
# Enter the name : saree

# %%
len(saree_img_link)
# Out:
# 313

# %%
saree_img_link
# Out:
# ['https://m.media-amazon.com/images/I/61MvfTLNxNL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81a+iWz+23S._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/810ppvdOkxS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71uW1yzU1PL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71xE92l+GGL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81Ln2cqtsLL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91WCQ88UV5L._AC_UL320_.jpg',
#  'https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/aa8a2144-7305-4eb7-aeac-639c8510074c._CR0,0,500,500_SX50_._TTW_.jpg',
#  'https://m.media-amazon.com/images/I/715NYXDhD-L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81JE98ug38L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/713f+6CnyNL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81XKaSKvlyL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81XKaSKvlyL._AC_UL320_.jpg',
# ...

# %%
product_images('https://www.amazon.in/',jeans_img_link)
# Out:
# Enter the name : denim jeans

# %%
len(jeans_img_link)
# Out:
# 351

# %%
shorts_img_link.clear()

# %%
product_images('https://www.amazon.in/',shorts_img_link)
# Out:
# Enter the name : shorts

# %%
len(shorts_img_link)
# Out:
# 360

# %%
product_images('https://www.amazon.in/',shirts_img_link)
# Out:
# Enter the name : shirts

# %%
len(shirts_img_link)
# Out:
# 376

# %%
import requests
from bs4 import BeautifulSoup
import html5lib

# %%
for i in range(len(saree_img_link)):

    print("Downloading", i , "of", len(saree_img_link))
    response= requests.get(saree_img_link[i])
    file = open("C:/Flip Robo/Image Scraping and Classification Project/data collection/saree images/img"+str(i)+".jpg", "wb") #saaving files in folder in c drive
    file.write(response.content)

# %%
for i in range(len(jeans_img_link)):

    print("Downloading", i , "of", len(jeans_img_link))
    response= requests.get(jeans_img_link[i])
    file = open("C:/Flip Robo/Image Scraping and Classification Project/data collection/jeans images/img"+str(i)+".jpg", "wb") #saaving files in folder in c drive
    file.write(response.content)

# %%
for i in range(len(shorts_img_link)):

    print("Downloading", i , "of", len(shorts_img_link))
    response= requests.get(shorts_img_link[i])
    file = open("C:/Flip Robo/Image Scraping and Classification Project/data collection/shorts images/img"+str(i)+".jpg", "wb") #saaving files in folder in c drive
    file.write(response.content)

# %%
for i in range(len(shirts_img_link)):

    print("Downloading", i , "of", len(shirts_img_link))
    response= requests.get(shirts_img_link[i])
    file = open("C:/Flip Robo/Image Scraping and Classification Project/data collection/shirts images/img"+str(i)+".jpg", "wb") #saaving files in folder in c drive
    file.write(response.content)
